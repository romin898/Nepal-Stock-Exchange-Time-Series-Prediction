# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt



def get_df():
    df=pd.DataFrame()
    files = os.listdir()
    df = pd.concat([pd.read_csv(f) for f in files if f.endswith('.csv')],index=False)

#df1=get_df()


#df.to_csv(f"file_name.csv")
df = pd.read_excel('a.xlsx',parse_dates=True)
df = df[['BUSINESS_DATE','SYMBOL','CLOSE_PRICE','PREVIOUS_DAY_CLOSE_PRICE','LAST_UPDATED_PRICE']]
df['LAST_UPDATED_PRICE'] = pd.to_numeric(df['LAST_UPDATED_PRICE'], errors='coerce')
df['LAST_UPDATED_PRICE'].dropna(inplace=True)
print(df.tail())
df.info()
df['RETURN']=((df['LAST_UPDATED_PRICE'] - df['PREVIOUS_DAY_CLOSE_PRICE'])/df['PREVIOUS_DAY_CLOSE_PRICE'])*100
df = df[df['BUSINESS_DATE']>'2023-2-7']
df_grp = df.groupby('SYMBOL')['RETURN'].mean()
#print(df_grp.sort_values().to_string())


def get_sectoral_average(filename,sector):
    df1 = pd.read_excel(filename,parse_dates=True)
    df1 = df1[['BUSINESS_DATE','SYMBOL','CLOSE_PRICE','PREVIOUS_DAY_CLOSE_PRICE','LAST_UPDATED_PRICE']]
    df1 = df1[df1['BUSINESS_DATE']>'2023-2-7']
    df1['LAST_UPDATED_PRICE'] = pd.to_numeric(df1['LAST_UPDATED_PRICE'], errors='coerce')
    df1['LAST_UPDATED_PRICE'].dropna(inplace=True)
    df2 = pd.read_excel(sector)
    df2_list = list(df2['Symbol'])
    df1 = df1[df1['SYMBOL'].isin(df2_list)]
    df1['RETURN']=((df1['LAST_UPDATED_PRICE'] - df1['PREVIOUS_DAY_CLOSE_PRICE'])/df1['PREVIOUS_DAY_CLOSE_PRICE'])*100
    df1_grp = df1.groupby('SYMBOL')['RETURN'].mean()
    return (df1_grp.sort_values().to_string())


print("Banks only")
print(get_sectoral_average('a.xlsx','HYDROPOWER_INFORMATION.xlsx'))
#print(get_sectoral_average('a.xlsx','BANK_INFORMATION.xlsx'))
# Out:
#      BUSINESS_DATE SYMBOL  CLOSE_PRICE  PREVIOUS_DAY_CLOSE_PRICE  \
# 6935    2023-02-26   SBCF         7.89                      8.05
# 6936    2023-02-26    BHL       351.00                    347.80
# 6937    2023-02-26   SGHC       377.00                    379.90
# 6938    2023-02-26  USHEC       357.00                    352.00
# 6939    2023-02-26   PHCL       364.90                    362.00
#
#       LAST_UPDATED_PRICE
# 6935                7.89
# 6936              351.00
# 6937              377.00
# 6938              357.00
# 6939              364.90
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6940 entries, 0 to 6939
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   BUSINESS_DATE             6940 non-null   datetime64[ns]
#  1   SYMBOL                    6940 non-null   object
#  2   CLOSE_PRICE               6940 non-null   float64
#  3   PREVIOUS_DAY_CLOSE_PRICE  6940 non-null   float64
#  4   LAST_UPDATED_PRICE        6931 non-null   float64
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 271.2+ KB
# Banks only
# SYMBOL
# SSHL     -1.199127
# MHNL     -1.164879
# HPPL     -1.118862
# SPDL     -1.081537
# UPPER    -1.069784
# UMRH     -0.983478
# SHPC     -0.871959
# UHEWA    -0.870822
# SHEL     -0.861585
# AKJCL    -0.807056
# SAHAS    -0.797641
# PMHPL    -0.794277
# UMHL     -0.757538
# HDHPC    -0.738445
# UNHPL    -0.705894
# GHL      -0.691199
# CHCL     -0.682287
# UPCL     -0.677000
# NGPL     -0.668576
# MEN      -0.650693
# PHCL     -0.650010
# USHEC    -0.633074
# SPHL     -0.632515
# GVL      -0.631053
# MHL      -0.618832
# HURJA    -0.606295
# RHPL     -0.586939
# SJCL     -0.580907
# MKJC     -0.571648
# DHPL     -0.570471
# BARUN    -0.509302
# SGHC     -0.503047
# NHPC     -0.499695
# BHL      -0.484519
# BPCL     -0.483114
# AHPC     -0.478896
# KKHC     -0.465736
# API      -0.464860
# AKPL     -0.460270
# RIDI     -0.457292
# BNHC     -0.434198
# MBJC     -0.418514
# JOSHI    -0.407365
# RURU     -0.381334
# RADHI    -0.315754
# GLH      -0.315745
# PPCL     -0.305109
# SIKLES   -0.292913
# LEC      -0.235672
# EHPL     -0.198059
# RFPL     -0.110040
# KPCL     -0.098253
# PPL      -0.011500
# NYADI     0.127895
# BHDC      0.166228
# HHL       0.265092
# DORDI     0.410988
# TPC       0.426688
# NHDL      0.520270
# BHPL      0.862544
# CHL       1.035574
# SPC       1.198740
# RHGCL     2.206295
